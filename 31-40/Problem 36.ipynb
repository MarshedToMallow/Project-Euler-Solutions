# %% [markdown]
# # Double-base Palindromes - Problem 36
#
# The decimal number, $585=1001001001_2$ (binary), is palindromic in both bases.
#
# Find the sum of all numbers, less than one million, which are palindromic in base 10 and base 2.
#
# (Please note that the palindromic number, in either base, may not include leading zeros.)

# %% [markdown]
# # My solution
#
# Iterating over every value from $1$ to $10^6-1$ and simply checking if they're pallindromes both in Decimal and Binary is sufficient.
#
# From there it's a simple matter of keeping a running total of all valid palindromes.

# %%
total = 0

for n in range(1, 10**6):
    if int(str(n)[::-1]) != n:continue
    if bin(n)[2:] != bin(n)[2:][::-1]:continue
    total += n

total
# Out:
# 872187
